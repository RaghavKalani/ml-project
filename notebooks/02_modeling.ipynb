# %% [markdown]
# # Phase 2: Stroke Prediction Modeling
#
# This notebook trains and evaluates imbalanced classification baselines. Recall and PR-AUC are emphasized because stroke cases are the minority class.

# %%
from pathlib import Path
import sys

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent
sys.path.insert(0, str(project_root))

from src.train_model import run

run()

# %% [markdown]
# ## Generated outputs
#
# - `reports/model_metrics.csv`: test-set comparison
# - `reports/threshold_metrics.csv`: precision/recall trade-offs
# - `reports/cross_validation_pr_auc.txt`: 5-fold validation
# - `reports/ML_Model_Report.md`: written evaluation
# - `models/stroke_model.pkl`: selected fitted pipeline
# - `figures/*_confusion_matrix.png`: confusion matrices
